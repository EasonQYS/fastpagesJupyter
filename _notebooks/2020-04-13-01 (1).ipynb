# %% [markdown]
# # 数学符号
# > An easy to use blogging platform with extra features for Jupyter Notebooks.
#
# - toc: true
# - badges: true
# - comments: true
# - author: Jeremy Howard & Hamel Husain
# - image: images/diagram.png
# - categories: [fastpages, jupyter]

# %% [markdown]
# ### LaTeX
#
# $\sqrt{2}$
#
# $$\mathbb{Z} = \{. . . ,−2,−1, 0, 1, 2, . . .\}$$
#
# $$e = \lim_{n \to \infty}(1 + {\frac 1 n})^n,$$
# $$e = \lim_{\varepsilon \to 0}(1 + \varepsilon)^{\frac 1 \varepsilon},$$
# $$e = \sum_{n = 0}^{\infty}{\frac 1 {n!}}.$$
#
# $$Pow(2,1/2)*Pow(2,1/2)= 2.$$

# %% [markdown]
# If you want to completely hide cells (not just collapse them), [read these instructions](https://github.com/fastai/fastpages#hide-inputoutput-cells).

# %% [markdown]
# ### 本地图片
#
# ![%5Bstudydata_phone%5D%E6%B6%88%E6%81%AF%E7%9B%91%E6%8E%A7%20%281%29.png](attachment:%5Bstudydata_phone%5D%E6%B6%88%E6%81%AF%E7%9B%91%E6%8E%A7%20%281%29.png)

# %% [markdown]
# ### 网页图片
#
# You can include markdown images with captions like this:
#
# ```
# ![](https://www.fast.ai/images/fastai_paper/show_batch.png "Credit: https://www.fast.ai/2020/02/13/fastai-A-Layered-API-for-Deep-Learning/")
# ```
#
#
# ![](https://www.fast.ai/images/fastai_paper/show_batch.png "Credit: https://www.fast.ai/2020/02/13/fastai-A-Layered-API-for-Deep-Learning/")
#
# Of course, the caption is optional.
